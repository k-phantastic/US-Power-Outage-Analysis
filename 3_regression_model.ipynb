# %%
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
pd.options.plotting.backend = 'plotly'

from utils import * 

# For widescreen display, overrides utils.py settings
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Regression --> Predicting Outage Duration

# %%
# Load cleaned dataset
file_path = 'data/cleaned_outage_dataset.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    YEAR  MONTH U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION  \
# 0  2011    7.0  Minnesota          MN         MRO  East North Central
# 1  2014    5.0  Minnesota          MN         MRO  East North Central
# 2  2010   10.0  Minnesota          MN         MRO  East North Central
# 3  2012    6.0  Minnesota          MN         MRO  East North Central
# 4  2015    7.0  Minnesota          MN         MRO  East North Central
#
#    ANOMALY.LEVEL CLIMATE.CATEGORY OUTAGE.START.DATE OUTAGE.START.TIME  \
# 0           -0.3           normal        2011-07-01          17:00:00
# 1           -0.1           normal        2014-05-11          18:38:00
# 2           -1.5             cold        2010-10-26          20:00:00
# 3           -0.1           normal        2012-06-19          04:30:00
# 4            1.2             warm        2015-07-18          02:00:00
#
#   OUTAGE.RESTORATION.DATE OUTAGE.RESTORATION.TIME      CAUSE.CATEGORY  \
# 0              2011-07-03                20:00:00      severe weather
# 1              2014-05-11                18:39:00  intentional attack
# 2              2010-10-28                22:00:00      severe weather
# 3              2012-06-20                23:00:00      severe weather
# 4              2015-07-19                07:00:00      severe weather
#
#   CAUSE.CATEGORY.DETAIL HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  \
# 0                   NaN             NaN           3060.0             NaN
# 1             vandalism             NaN              1.0             NaN
# 2            heavy wind             NaN           3000.0             NaN
# 3          thunderstorm             NaN           2550.0             NaN
# 4                   NaN             NaN           1740.0           250.0
#
#    CUSTOMERS.AFFECTED  RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  \
# 0             70000.0      11.60       9.18       6.81         9.28
# 1                 NaN      12.12       9.71       6.49         9.28
# 2             70000.0      10.87       8.19       6.07         8.15
# 3             68200.0      11.79       9.25       6.71         9.19
# 4            250000.0      13.07      10.16       7.74        10.43
#
#    RES.SALES  COM.SALES  IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  \
# 0   2.33e+06   2.11e+06   2.11e+06     6.56e+06       35.55       32.23
# 1   1.59e+06   1.81e+06   1.89e+06     5.28e+06       30.03       34.21
# 2   1.47e+06   1.80e+06   1.95e+06     5.22e+06       28.10       34.50
# 3   1.85e+06   1.94e+06   1.99e+06     5.79e+06       31.99       33.54
# 4   2.03e+06   2.16e+06   1.78e+06     5.97e+06       33.98       36.21
#
#    IND.PERCEN  RES.CUSTOMERS  COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  \
# 0       32.20       2.31e+06       276286.0        10673.0         2.60e+06
# 1       35.73       2.35e+06       284978.0         9898.0         2.64e+06
# 2       37.37       2.30e+06       276463.0        10150.0         2.59e+06
# 3       34.44       2.32e+06       278466.0        11010.0         2.61e+06
# 4       29.78       2.37e+06       289044.0         9812.0         2.67e+06
#
#    RES.CUST.PCT  COM.CUST.PCT  IND.CUST.PCT  PC.REALGSP.STATE  PC.REALGSP.USA  \
# 0         88.94         10.64          0.41           51268.0         47586.0
# 1         88.83         10.79          0.37           53499.0         49091.0
# 2         88.92         10.69          0.39           50447.0         47287.0
# 3         88.90         10.68          0.42           51598.0         48156.0
# 4         88.82         10.81          0.37           54431.0         49844.0
#
#    PC.REALGSP.REL  PC.REALGSP.CHANGE  UTIL.REALGSP  TOTAL.REALGSP  \
# 0            1.08                1.6        4802.0       274182.0
# 1            1.09                1.9        5226.0       291955.0
# 2            1.07                2.7        4571.0       267895.0
# 3            1.07                0.6        5364.0       277627.0
# 4            1.09                1.7        4873.0       292023.0
#
#    UTIL.CONTRI  PI.UTIL.OFUSA  POPULATION  POPPCT_URBAN  POPPCT_UC  \
# 0         1.75            2.2     5348119         73.27      15.28
# 1         1.79            2.2     5457125         73.27      15.28
# 2         1.71            2.1     5310903         73.27      15.28
# 3         1.93            2.2     5380443         73.27      15.28
# 4         1.67            2.2     5489594         73.27      15.28
#
#    POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  AREAPCT_URBAN  AREAPCT_UC  PCT_LAND  \
# 0        2279.0     1700.5          18.2           2.14         0.6     91.59
# 1        2279.0     1700.5          18.2           2.14         0.6     91.59
# 2        2279.0     1700.5          18.2           2.14         0.6     91.59
# 3        2279.0     1700.5          18.2           2.14         0.6     91.59
# 4        2279.0     1700.5          18.2           2.14         0.6     91.59
#
#    PCT_WATER_TOT  PCT_WATER_INLAND         OUTAGE.START   OUTAGE.RESTORATION  \
# 0           8.41              5.48  2011-07-01 17:00:00  2011-07-03 20:00:00
# 1           8.41              5.48  2014-05-11 18:38:00  2014-05-11 18:39:00
# 2           8.41              5.48  2010-10-26 20:00:00  2010-10-28 22:00:00
# 3           8.41              5.48  2012-06-19 04:30:00  2012-06-20 23:00:00
# 4           8.41              5.48  2015-07-18 02:00:00  2015-07-19 07:00:00
#
#   MONTH.NAME
# 0        Jul
# 1        May
# 2        Oct
# 3        Jun
# 4        Jul

# %% [markdown]
# ## Heavy skew in outage durations, most last less than 2 days

# %%
# Plot outage duration distribution
fig = px.histogram(df, x='OUTAGE.DURATION', nbins=100, title='Distribution of Outage Durations (Minutes)')
fig.update_layout(xaxis_title='Outage Duration (Minutes)', yaxis_title='Count')
fig.show()

# Plot log outage duration distribution
fig = px.histogram(df, x=np.log1p(df['OUTAGE.DURATION']), nbins=30, title='Distribution of Log Outage Durations (Minutes)')
fig.update_layout(xaxis_title='Log Outage Duration (Minutes)', yaxis_title='Count')
fig.show()
# Out:
# <div>                            <div id="0e7e2e1d-8f91-46c3-b526-fc1be55ce9cd" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e7e2e1d-8f91-46c3-b526-fc1be55ce9cd")) {                    Plotly.newPlot(                        "0e7e2e1d-8f91-46c3-b526-fc1be55ce9cd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"OUTAGE.DURATION=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[3060.0,1.0,3000.0,2550.0,1740.0,1860.0,2970.0,3960.0,155.0,3621.0,7740.0,8880.0,0.0,1322.0,60.0,19.0,0.0,21.0,196.0,840.0,935.0,1260.0,null,619.0,150.0,762.0,0.0,660.0,1.0,2700.0,1.0,4921.0,95.0,251.0,4125.0,2550.0,null,1200.0,310.0,2818.0,5054.0,136.0,528.0,46.0,1.0,1920.0,null,32.0,null,135.0,3000.0,32.0,108653.0,8468.0,960.0,44.0,1605.0,4410.0,388.0,480.0,1219.0,90.0,18660.0,538.0,104.0,60.0,1272.0,60.0,1.0,1000.0,17339.0,9576.0,3090.0,6510.0,5820.0,1078.0,1513.0,4830.0,3051.0,4200.0,2085.0,5730.0,4290.0,2670.0,3540.0,3637.0,1710.0,4320.0,3915.0,3120.0,4590.0,7530.0,5034.0,8160.0,3300.0,4320.0,1770.0,9857.0,4080.0,